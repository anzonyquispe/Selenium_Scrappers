# %% [markdown]
# # Web Scraping SBS

# %% [markdown]
# ## Herramientas
#
# - Chromdriver
# - Selenium
#     - Selectors
#     - Frames
#     - Input
# - Pandas
# - For Loop
# - While Loop

# %% [markdown]
# ## ChromeDriver

# %%
# !pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# ## Selenium

# %%
#!pip install selenium
from selenium import webdriver

# %% [markdown]
# Iniciamos con dos primeras lineas que sirven para setear la forma de presentación de la pantalla. Luego, en una sola línea utilizamos ChromeDriver y Selenium

# %%
# Setting
options= Options()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(ChromeDriverManager().install(),options=options)
# With this option we connect with the URL we desire
driver.get("https://www.sbs.gob.pe/app/pp/EstadisticasSAEEPortal/Paginas/TIActivaTipoCreditoEmpresa.aspx?tip=B#")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 106.0.5249
# Get LATEST chromedriver version for 106.0.5249 google-chrome
# There is no [win32] chromedriver for browser  in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/106.0.5249.61/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Anzony\.wdm\drivers\chromedriver\win32\106.0.5249.61]

# %% [markdown]
# ## Explorando Html
#
# Empezaremos explorando la página y viendo cómo poder obtener la tabla default utilizando selenium. Para ello vamos a inspeccionar la página y ver que cada elemento tiene una forma de seleccionar. Toda página está hecha a través de HTML5 que permite maquetar la página y colocar cada cosa que vemos dentro de una caja. Caminando sobre los elementos podemos llegar a cada caja. Ejemplo:

# %%
driver.find_element_by_id( "ctl00_cphContent_btnConsultar" ).get_attribute( "value")
# Out:
# 'Consultar'

# %%
driver.find_element_by_css_selector('#ctl00_cphContent_divConsultarDiario > table > tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td.APLI_txtCampo > div').text
# Out:
# 'Ingrese fecha: '

# %%
driver.find_element_by_xpath( "/html/body/form/div[4]/div/div/div[1]/table/tbody/tr/td/div/span").text
# Out:
# 'TASA DE INTERÉS PROMEDIO DEL SISTEMA BANCARIO'

# %% [markdown]
# Podemos identificar los elementos a través de un ID, Selector, FullXpath o Xpath. Con ello identificamos cada elemento. Además, podemos interactuar con ellos. Dar click o inputear alguna información.

# %% [markdown]
# Click

# %%
driver.find_element_by_id("ctl00_cphContent_lbtnMex").click()

# %% [markdown]
# Input Value

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '04/07/2007'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)


driver.find_element_by_xpath("/html/body/form/table")

# %% [markdown]
# **¿Por qué no podemos obtener este elemento si existe en la maqueta de html?**
#
#
# Porque este elemento esta dentro de otro html que a su vez está embebido a esta página web.

# %%
# Cambiamos de frame
driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))

# %%
# Seleccionamos la tabla
tabla = driver.find_element_by_xpath("/html/body/form/table")

# %% [markdown]
# ### ¿Cómo lidiamos con las tablas?
#
# La forma más fácil es usando pandas para leer html. Pandas te permite importar datos desde una estructura HTML. La estructura de las tablas cambia para fechas antiguas y para fechas modernas.

# %% [markdown]
# #### Antiguos

# %%
# Input date
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '30/10/2015'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep(2)
# Cambiamos de frame
driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))
driver.find_element_by_xpath("/html/body/form/table")
# Seleccionamos la tabla
tabla = driver.find_element_by_xpath("/html/body/form/table")

tabla_html = tabla.get_attribute('outerHTML')
# Volvemos al frame principal
driver.switch_to.default_content()

# %%
import pandas as pd
tablas = pd.read_html(tabla_html)

# %%
tabla_reducida = tablas[2].iloc[2:, :]
tabla_reducida

# %%
tabla_reducida.to_excel( r"C:\Users\Anzony\Downloads/file.xlsx", index = False, header= False )

# %% [markdown]
# ### Recientes

# %%
# Input date
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '30/11/2015'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep(2)

# Identificar directamente la tabla
# Seleccionamos la tabla
tabla = driver.find_element_by_id("ctl00_cphContent_rpgActualMn_OT")
tabla_html = tabla.get_attribute('outerHTML')

# %%
tablas = pd.read_html(tabla_html)
tablas

# %%
import numpy as np

# %%
# generate table objects
table0, table1 = tablas[0], tablas[1]
table_clean = table1.copy()

# Number of rows of second table
tb1_rows = table1.shape[0]
drop_rows = np.arange( 1, tb1_rows + 2 )

# Clean first table
table0 = table0.drop( drop_rows, axis = 0 )

# Assign values to new table
col_name = table0.iloc[0, 0]
col_values = table0.iloc[1:, 0].tolist()
table_clean.insert( loc = 0, column= col_name, value = col_values)
table_clean1 = table_clean.copy()
table_clean1

# %% [markdown]
# Conseguimos exportar nuestra primera tabla. Ahora, tenemos que hacer esto para todas las últimsa fechas de cada mes donde haya disponible información de la SBS. Por lo tanto, tenemos que introducir información en el input de fecha y hacer la consulta para cada fecha.

# %% [markdown]
# **¿Cómo conseguimos las última fechas de cada mes?**
#
# Vamos a utilizar la herramienta datetime de pandas.

# %%
# Generamos un rango de fechas
data_date = pd.DataFrame( {'date_real' : pd.date_range(start="01-01-2013",end="08-31-2022") })
data_date
# Out:
#       date_real
# 0    2013-01-01
# 1    2013-01-02
# 2    2013-01-03
# 3    2013-01-04
# 4    2013-01-05
# ...         ...
# 3525 2022-08-27
# 3526 2022-08-28
# 3527 2022-08-29
# 3528 2022-08-30
# 3529 2022-08-31
#
# [3530 rows x 1 columns]

# %%
# Les damos un formato y separamos los dias meses y años
data_date['date_info'] = data_date.date_real.dt.strftime("%d/%m/%Y")
data_split = data_date.date_info.str.split("/", expand= True ).astype(int)
data_split.columns = ["Day", "Month", "Year"]
data_date = pd.concat([ data_date, data_split ], axis = 1 )
data_date
# Out:
#       date_real   date_info  Day  Month  Year
# 0    2013-01-01  01/01/2013    1      1  2013
# 1    2013-01-02  02/01/2013    2      1  2013
# 2    2013-01-03  03/01/2013    3      1  2013
# 3    2013-01-04  04/01/2013    4      1  2013
# 4    2013-01-05  05/01/2013    5      1  2013
# ...         ...         ...  ...    ...   ...
# 3525 2022-08-27  27/08/2022   27      8  2022
# 3526 2022-08-28  28/08/2022   28      8  2022
# 3527 2022-08-29  29/08/2022   29      8  2022
# 3528 2022-08-30  30/08/2022   30      8  2022
# 3529 2022-08-31  31/08/2022   31      8  2022
#
# [3530 rows x 5 columns]

# %%
# Tomamos la última fecha
data_date['date_real'] = pd.to_datetime(data_date.date_info, format="%d/%m/%Y")
# Get the last 5 days per month
final_date_data = data_date.sort_values('date_real').groupby([ "Year" , "Month" ]).tail(1).reset_index(drop = True)
dates_list = final_date_data.date_real.tolist()
dates_list
# Out:
# [Timestamp('2013-01-31 00:00:00'),
#  Timestamp('2013-02-28 00:00:00'),
#  Timestamp('2013-03-31 00:00:00'),
#  Timestamp('2013-04-30 00:00:00'),
#  Timestamp('2013-05-31 00:00:00'),
#  Timestamp('2013-06-30 00:00:00'),
#  Timestamp('2013-07-31 00:00:00'),
#  Timestamp('2013-08-31 00:00:00'),
#  Timestamp('2013-09-30 00:00:00'),
#  Timestamp('2013-10-31 00:00:00'),
#  Timestamp('2013-11-30 00:00:00'),
#  Timestamp('2013-12-31 00:00:00'),
#  Timestamp('2014-01-31 00:00:00'),
#  Timestamp('2014-02-28 00:00:00'),
#  Timestamp('2014-03-31 00:00:00'),
#  Timestamp('2014-04-30 00:00:00'),
#  Timestamp('2014-05-31 00:00:00'),
#  Timestamp('2014-06-30 00:00:00'),
#  Timestamp('2014-07-31 00:00:00'),
#  Timestamp('2014-08-31 00:00:00'),
#  Timestamp('2014-09-30 00:00:00'),
#  Timestamp('2014-10-31 00:00:00'),
#  Timestamp('2014-11-30 00:00:00'),
#  Timestamp('2014-12-31 00:00:00'),
#  Timestamp('2015-01-31 00:00:00'),
#  Timestamp('2015-02-28 00:00:00'),
#  Timestamp('2015-03-31 00:00:00'),
#  Timestamp('2015-04-30 00:00:00'),
#  Timestamp('2015-05-31 00:00:00'),
#  Timestamp('2015-06-30 00:00:00'),
#  Timestamp('2015-07-31 00:00:00'),
#  Timestamp('2015-08-31 00:00:00'),
#  Timestamp('2015-09-30 00:00:00'),
#  Timestamp('2015-10-31 00:00:00'),
#  Timestamp('2015-11-30 00:00:00'),
#  Timestamp('2015-12-31 00:00:00'),
#  Timestamp('2016-01-31 00:00:00'),
#  Timestamp('2016-02-29 00:00:00'),
#  Timestamp('2016-03-31 00:00:00'),
#  Timestamp('2016-04-30 00:00:00'),
#  Timestamp('2016-05-31 00:00:00'),
#  Timestamp('2016-06-30 00:00:00'),
#  Timestamp('2016-07-31 00:00:00'),
#  Timestamp('2016-08-31 00:00:00'),
#  Timestamp('2016-09-30 00:00:00'),
#  Timestamp('2016-10-31 00:00:00'),
#  Timestamp('2016-11-30 00:00:00'),
#  Timestamp('2016-12-31 00:00:00'),
#  Timestamp('2017-01-31 00:00:00'),
#  Timestamp('2017-02-28 00:00:00'),
#  Timestamp('2017-03-31 00:00:00'),
#  Timestamp('2017-04-30 00:00:00'),
#  Timestamp('2017-05-31 00:00:00'),
#  Timestamp('2017-06-30 00:00:00'),
#  Timestamp('2017-07-31 00:00:00'),
#  Timestamp('2017-08-31 00:00:00'),
#  Timestamp('2017-09-30 00:00:00'),
#  Timestamp('2017-10-31 00:00:00'),
#  Timestamp('2017-11-30 00:00:00'),
#  Timestamp('2017-12-31 00:00:00'),
#  Timestamp('2018-01-31 00:00:00'),
#  Timestamp('2018-02-28 00:00:00'),
#  Timestamp('2018-03-31 00:00:00'),
#  Timestamp('2018-04-30 00:00:00'),
#  Timestamp('2018-05-31 00:00:00'),
#  Timestamp('2018-06-30 00:00:00'),
#  Timestamp('2018-07-31 00:00:00'),
#  Timestamp('2018-08-31 00:00:00'),
#  Timestamp('2018-09-30 00:00:00'),
#  Timestamp('2018-10-31 00:00:00'),
#  Timestamp('2018-11-30 00:00:00'),
#  Timestamp('2018-12-31 00:00:00'),
#  Timestamp('2019-01-31 00:00:00'),
#  Timestamp('2019-02-28 00:00:00'),
#  Timestamp('2019-03-31 00:00:00'),
#  Timestamp('2019-04-30 00:00:00'),
#  Timestamp('2019-05-31 00:00:00'),
#  Timestamp('2019-06-30 00:00:00'),
#  Timestamp('2019-07-31 00:00:00'),
#  Timestamp('2019-08-31 00:00:00'),
#  Timestamp('2019-09-30 00:00:00'),
#  Timestamp('2019-10-31 00:00:00'),
#  Timestamp('2019-11-30 00:00:00'),
#  Timestamp('2019-12-31 00:00:00'),
#  Timestamp('2020-01-31 00:00:00'),
#  Timestamp('2020-02-29 00:00:00'),
#  Timestamp('2020-03-31 00:00:00'),
#  Timestamp('2020-04-30 00:00:00'),
#  Timestamp('2020-05-31 00:00:00'),
#  Timestamp('2020-06-30 00:00:00'),
#  Timestamp('2020-07-31 00:00:00'),
#  Timestamp('2020-08-31 00:00:00'),
#  Timestamp('2020-09-30 00:00:00'),
#  Timestamp('2020-10-31 00:00:00'),
#  Timestamp('2020-11-30 00:00:00'),
#  Timestamp('2020-12-31 00:00:00'),
#  Timestamp('2021-01-31 00:00:00'),
#  Timestamp('2021-02-28 00:00:00'),
#  Timestamp('2021-03-31 00:00:00'),
#  Timestamp('2021-04-30 00:00:00'),
#  Timestamp('2021-05-31 00:00:00'),
#  Timestamp('2021-06-30 00:00:00'),
#  Timestamp('2021-07-31 00:00:00'),
#  Timestamp('2021-08-31 00:00:00'),
#  Timestamp('2021-09-30 00:00:00'),
#  Timestamp('2021-10-31 00:00:00'),
#  Timestamp('2021-11-30 00:00:00'),
#  Timestamp('2021-12-31 00:00:00'),
#  Timestamp('2022-01-31 00:00:00'),
#  Timestamp('2022-02-28 00:00:00'),
#  Timestamp('2022-03-31 00:00:00'),
#  Timestamp('2022-04-30 00:00:00'),
#  Timestamp('2022-05-31 00:00:00'),
#  Timestamp('2022-06-30 00:00:00'),
#  Timestamp('2022-07-31 00:00:00'),
#  Timestamp('2022-08-31 00:00:00')]

# %% [markdown]
# Tenemos una lista de los último días de cada mes desde 2000 al 2022. La idea es empezar en este día e ir probando hacia atrás hasta encontrarnos con el último día en el que se haya reportado información. Para hacer este proceso iterativo utilizaremos un while loop.
#
# While loop es un proceso iterativo que se repite hasta que cierta condición se cumple. Para nuestro caso, hasta que hayamos encontrado una tabla. Ahora, debemos tener en cuenta que el driver puede enfrentarse a dos tipos de tablas como las que ya vimos arriba. Todo esto lo tendremos que tomar en cuenta.

# %% [markdown]
# Primero, iniciemos con una fecha última la cual no tiene tabla "31/07/2022".

# %%
import time

# 
# le damos el fomato que queremos
last_day = dates_list[-2]
last_day_str = last_day.strftime("%d/%m/%Y")
print(last_day_str)

# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
# Out:
# 31/07/2022

# %% [markdown]
# Lo que hariamos es ir a un dia anterior "30/07/2022".

# %%
# Vamos un dia anterior
from datetime import datetime, timedelta
last_day = last_day - timedelta(days= 1)
last_day_str = last_day.strftime("%d/%m/%Y")
print(last_day_str)


# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
# Out:
# 30/07/2022

# %% [markdown]
# Como esta fecha tampoco tiene tabla tenemos que ir a un día anterior "29/07/2022".

# %%
# Vamos un dia anterior
from datetime import datetime, timedelta
last_day = last_day - timedelta(days= 1)
last_day_str = last_day.strftime("%d/%m/%Y")
print(last_day_str)


# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
# Out:
# 29/07/2022

# %% [markdown]
# Una vez más "28/07/2022".

# %%
# Vamos un dia anterior
from datetime import datetime, timedelta
last_day = last_day - timedelta(days= 1)
last_day_str = last_day.strftime("%d/%m/%Y")
print(last_day_str)


# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
# Out:
# 28/07/2022

# %% [markdown]
# Una vez más "27/07/2022".

# %%
# Vamos un dia anterior
from datetime import datetime, timedelta
last_day = last_day - timedelta(days= 1)
last_day_str = last_day.strftime("%d/%m/%Y")
print(last_day_str)


# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
# Out:
# 27/07/2022

# %% [markdown]
# Aquí, sí encontramos información. Entonces, el scrpaer tiene que recorrer hacia atrás hasta encontrar una tabla. Esto lo podemos hacer utilizando los ojos, pero como lo haría el scraper. Bueno, provando si existe una table como las antiguas o las recientes. Para eso utilizaremos `try`.

# %%
# le damos el fomato que queremos
last_day_str = "31/07/2022"
print(last_day_str)

# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )

# busquems la tabla
# prueba si es una tabla tipo antigua
try:
    # Cambiamos de frame
    driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))
    driver.find_element_by_xpath("/html/body/form/table")
    # Seleccionamos la tabla
    tabla = driver.find_element_by_xpath("/html/body/form/table")

    tabla_html = tabla.get_attribute('outerHTML')
    # Volvemos al frame principal
    driver.switch_to.default_content()
    tablas = pd.read_html(tabla_html)
    tabla_reducida = tablas[2].iloc[2:, :]
    tabla_reducida
    # Dame el numero de columnas
    print( "Tenemos una tabla tipo antigua")
except:
    print( "No Tenemos una tabla tipo antigua")
# Out:
# 31/07/2022
# No Tenemos una tabla tipo antigua

# %%
# Probemos una tabla reciente
# le damos el fomato que queremos
last_day_str = "31/07/2022"
print(last_day_str)

# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 2 )
try:

    # Identificar directamente la tabla
    # Seleccionamos la tabla
    tabla = driver.find_element_by_id("ctl00_cphContent_rpgActualMn_OT")
    tabla_html = tabla.get_attribute('outerHTML')
    tablas = pd.read_html(tabla_html)
    tablas
    # generate table objects
    table0, table1 = tablas[0], tablas[1]
    table_clean = table1.copy()

    # Number of rows of second table
    tb1_rows = table1.shape[0]
    drop_rows = np.arange( 1, tb1_rows + 2 )

    # Clean first table
    table0 = table0.drop( drop_rows, axis = 0 )

    # Assign values to new table
    col_name = table0.iloc[0, 0]
    col_values = table0.iloc[1:, 0].tolist()
    table_clean.insert( loc = 0, column= col_name, value = col_values)
    table_clean1 = table_clean.copy()
    table_clean1
    print("Tenemos Una tabla Reciente")
except:
    print("No Tenemos Una tabla Reciente")
# Out:
# 31/07/2022
# No Tenemos Una tabla Reciente

# %% [markdown]
# Como no tenemos ni tabla reciente, ni antigua, entonces probemos con el dia que si sabemos que hay tabla

# %%
# le damos el fomato que queremos
last_day_str = "27/07/2022"
print(last_day_str)

# repetimos el proceso de obtener tablas
driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
time.sleep( 3 )

# busquems la tabla
# prueba si es una tabla tipo antigua
try:
    # Cambiamos de frame
    driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))
    driver.find_element_by_xpath("/html/body/form/table")
    # Seleccionamos la tabla
    tabla = driver.find_element_by_xpath("/html/body/form/table")

    tabla_html = tabla.get_attribute('outerHTML')
    # Volvemos al frame principal
    driver.switch_to.default_content()
    tablas = pd.read_html(tabla_html)
    tabla_reducida = tablas[2].iloc[2:, :]
    tabla_reducida
    # Dame el numero de columnas
    print( "Tenemos una tabla tipo antigua")
except:
    print( "No Tenemos una tabla tipo antigua")
    

try:

    # Identificar directamente la tabla
    # Seleccionamos la tabla
    tabla = driver.find_element_by_id("ctl00_cphContent_rpgActualMn_OT")
    tabla_html = tabla.get_attribute('outerHTML')
    tablas = pd.read_html(tabla_html)
    tablas
    # generate table objects
    table0, table1 = tablas[0], tablas[1]
    table_clean = table1.copy()

    # Number of rows of second table
    tb1_rows = table1.shape[0]
    drop_rows = np.arange( 1, tb1_rows + 2 )

    # Clean first table
    table0 = table0.drop( drop_rows, axis = 0 )

    # Assign values to new table
    col_name = table0.iloc[0, 0]
    col_values = table0.iloc[1:, 0].tolist()
    table_clean.insert( loc = 0, column= col_name, value = col_values)
    table_clean1 = table_clean.copy()
    table_clean1
    print("Tenemos Una tabla Reciente")
except:
    print("No Tenemos Una tabla Reciente")
# Out:
# 27/07/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente

# %% [markdown]
# Bien, ya vimos que pudimos identificar las tablas. Ahora, utilicemos el while loop para hacer esto automaticamente. Vamos a permitirle al driver que retroceda hasta una semana.

# %%
days_before = 0
last_day = dates_list[-2]
while days_before < 8:
    
    # le damos el fomato que queremos
    last_day_str = last_day.strftime("%d/%m/%Y")
    print(last_day_str)

    # repetimos el proceso de obtener tablas
    driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
    driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
    time.sleep( 4 )

    # busquems la tabla
    # prueba si es una tabla tipo antigua
    try:
        # Cambiamos de frame
        driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))
        driver.find_element_by_xpath("/html/body/form/table")
        # Seleccionamos la tabla
        tabla = driver.find_element_by_xpath("/html/body/form/table")

        tabla_html = tabla.get_attribute('outerHTML')
        # Volvemos al frame principal
        driver.switch_to.default_content()
        tablas = pd.read_html(tabla_html)
        tabla_antigua = tablas[2].iloc[2:, :]
        tabla_antigua
        # Dame el numero de columnas
        print( "Tenemos una tabla tipo antigua")
    except:
        print( "No Tenemos una tabla tipo antigua")
        tabla_antigua = ""


    try:

        # Identificar directamente la tabla
        # Seleccionamos la tabla
        tabla = driver.find_element_by_id("ctl00_cphContent_rpgActualMn_OT")
        tabla_html = tabla.get_attribute('outerHTML')
        tablas = pd.read_html(tabla_html)
        tablas
        # generate table objects
        table0, table1 = tablas[0], tablas[1]
        table_clean = table1.copy()

        # Number of rows of second table
        tb1_rows = table1.shape[0]
        drop_rows = np.arange( 1, tb1_rows + 2 )

        # Clean first table
        table0 = table0.drop( drop_rows, axis = 0 )

        # Assign values to new table
        col_name = table0.iloc[0, 0]
        col_values = table0.iloc[1:, 0].tolist()
        table_clean.insert( loc = 0, column= col_name, value = col_values)
        tabla_reciente = table_clean.copy()
        tabla_reciente
        print("Tenemos Una tabla Reciente")
    except:
        print("No Tenemos Una tabla Reciente")
        tabla_reciente = ""
        

    if ( ( isinstance( tabla_reciente, str ) == True ) and ( isinstance( tabla_antigua, str ) == True ) ):
        days_before = 1 + days_before
        last_day = last_day - timedelta(days= 1)
        
    elif ( isinstance( tabla_reciente, str ) == False ) and ( tabla_reciente.shape[1] > 5 ) :
        days_before = 8 
    
    elif ( isinstance( tabla_antigua, str ) == False ) and ( tabla_antigua.shape[1] > 5 ):
        days_before = 8
# Out:
# 31/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# 30/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# 29/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# 28/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# 27/07/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente

# %% [markdown]
# Encontramos la tabla y discrimanamos por tipo de tabla. Lo que faltaría es replicar este procedimiento para todas las últimas fechas que tenemos en la lista y esto lo hacemos utilizando el for loop.

# %%
for last_day in dates_list:
    days_before = 0
    
    while days_before < 8:
        driver.switch_to.default_content()
        # le damos el fomato que queremos
        last_day_str = last_day.strftime("%d/%m/%Y")
        print(last_day_str)

        # repetimos el proceso de obtener tablas
        driver.execute_script( f"document.getElementById('ctl00_cphContent_rdpDate_dateInput').value = '{last_day_str}'")
        driver.find_element_by_id("ctl00_cphContent_rdpDate_dateInput").send_keys(Keys.RETURN)
        time.sleep( 5 )

        # busquems la tabla
        # prueba si es una tabla tipo antigua
        try:
            # Cambiamos de frame
            driver.switch_to.frame(driver.find_element_by_id("ctl00_cphContent_pnContenidoAnteriorMnASP"))
            driver.find_element_by_xpath("/html/body/form/table")
            # Seleccionamos la tabla
            tabla = driver.find_element_by_xpath("/html/body/form/table")

            tabla_html = tabla.get_attribute('outerHTML')
            # Volvemos al frame principal
            driver.switch_to.default_content()
            tablas = pd.read_html(tabla_html)
            tabla_antigua = tablas[2].iloc[2:, :]
            tabla_antigua
            # Dame el numero de columnas
            print( "Tenemos una tabla tipo antigua")
        except:
            print( "No Tenemos una tabla tipo antigua")
            tabla_antigua = ""


        try:

            # Identificar directamente la tabla
            # Seleccionamos la tabla
            tabla = driver.find_element_by_id("ctl00_cphContent_rpgActualMn_OT")
            tabla_html = tabla.get_attribute('outerHTML')
            tablas = pd.read_html(tabla_html)
            tablas
            # generate table objects
            table0, table1 = tablas[0], tablas[1]
            table_clean = table1.copy()

            # Number of rows of second table
            tb1_rows = table1.shape[0]
            drop_rows = np.arange( 1, tb1_rows + 2 )

            # Clean first table
            table0 = table0.drop( drop_rows, axis = 0 )

            # Assign values to new table
            col_name = table0.iloc[0, 0]
            col_values = table0.iloc[1:, 0].tolist()
            table_clean.insert( loc = 0, column= col_name, value = col_values)
            tabla_reciente = table_clean.copy()
            tabla_reciente
            print("Tenemos Una tabla Reciente")
        except:
            print("No Tenemos Una tabla Reciente")
            tabla_reciente = ""


        if ( ( isinstance( tabla_reciente, str ) == False ) and ( tabla_reciente.shape[1] > 5 ) ):
            days_before = 8 
            print( tabla_reciente.columns.tolist() )

        elif ( ( isinstance( tabla_antigua, str ) == False ) and ( tabla_antigua.shape[1] > 5 ) ):
            days_before = 8 
            print( tabla_antigua.iloc[ :2, : ] )

        else:
            print( "la tabla no cumple con tener más de 5 columnas.")
            days_before = days_before + 1
            last_day = last_day - timedelta(days= 1)
            print( f"GO {days_before} before")
# Out:
# 31/01/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.28         -     6.19        7.68  6.11
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.68      5.11       5.37        -     -          -       8.90
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.98
# 28/02/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.58         -     6.35        6.75  6.56
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.78      5.40       5.43        -  7.15          -       9.53
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      6.03
# 31/03/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/03/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/03/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 28/03/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 4 before
# 27/03/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.91      9.00     5.93           -  7.08
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.63      5.81       5.32        -  7.29          -       8.79
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.79
# 30/04/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.61         -     6.04        6.50  6.30
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.51      5.81       5.21        -  7.30          -       8.89
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.42
# 31/05/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.57         -     6.04           -  6.28
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        5.21      5.69       5.48        -  7.30          -       8.85
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.41
# 30/06/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/06/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/06/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.81         -     5.71           -  6.38
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.95      6.05       5.44        -  7.30          -       8.65
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.30
# 31/07/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.23         -     5.53        6.85  6.35
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.93      6.07       5.42        -     -          -       8.50
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.41
# 31/08/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/08/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/08/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.16         -     5.95        8.44  6.79
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.80      6.09       5.69        -     -          -       8.95
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.67
# 30/09/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.26         -     5.49        8.49  6.57
#
#            6         7          8        9     10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  HSBC  Falabella  Santander
# 3        4.82      6.03       5.91        -     -          -       8.96
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.53
# 31/10/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.04         -     5.70        6.89  6.67
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.06      6.06       6.15        -          -          -       8.22
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.78
# 30/11/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/11/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.66         -     5.44        6.93  7.50
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.16      5.99       6.66        -       6.31          -       7.95
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.37
# 31/12/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/12/2013
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.20         -     5.19           -  7.50
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.26      5.86       6.03        -       6.31          -       7.79
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.41
# 31/01/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.20         -     5.19           -  7.50
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.26      5.86       6.03        -       6.31          -       7.79
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.41
# 28/02/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.40         -     6.00        6.75  7.34
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.08      6.18       6.09        -       7.77          -       7.48
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      6.03
# 31/03/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.53         -     5.66        6.99  7.34
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.91      6.28       6.80        -       7.26          -       7.47
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.82
# 30/04/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.77         -     5.72        7.44  6.52
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.11      6.32       6.66        -       7.29          -       7.34
#
#        13      14        15        16        17
# 2  Ripley  Azteca  Deutsche  Cencosud  Promedio
# 3       -       -         -         -      5.84
# 31/05/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/05/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.64         -     5.77        7.62  6.37
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.75      6.36       6.20        -       6.01          -       8.09
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.85
# 30/06/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.75         -     5.87        7.45  7.58
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.68      6.90       6.10        -       6.94          -       7.47
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.91
# 31/07/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.77         -     5.77        8.50  6.07
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.96      7.11       6.08        -       6.82          -       7.53
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.80
# 31/08/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/08/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/08/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.75         -     5.47           -  5.98
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.47      6.82       5.55        -       7.02          -       8.14
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.58
# 30/09/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.72         -     5.04        6.15  5.89
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.77      7.01       6.63        -       6.67          -       7.33
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.29
# 31/10/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.66         -     5.51        5.80  5.98
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.64      6.58       6.54        -       8.39          -       7.38
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -  6.75      5.54
# 30/11/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/11/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/11/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.87         -     6.09        5.48  6.23
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.48      6.62       6.24        -       7.06          -       8.15
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -  6.00      5.81
# 31/12/2014
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.16         -     5.47        6.02  6.62
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.93      6.53       6.11        -       7.30          -       8.30
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.61
# 31/01/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/01/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.94         -     5.03        6.82  6.93
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.86      6.54       5.37        -       6.94          -       7.99
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.23
# 28/02/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 27/02/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.63         -     4.94        7.05  5.49
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.76      7.09       5.00        -       6.56          -       8.13
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -  6.91      5.12
# 31/03/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.50         -     5.10        5.95  5.44
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.78      6.91       6.00        -       7.58          -       8.03
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.19
# 30/04/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.55         -     4.92        6.36  6.32
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.61      5.89       5.75        -       7.68          -       7.84
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -  6.15      4.99
# 31/05/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/05/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/05/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.04         -     5.56        5.93  6.74
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.77      5.20       4.92        -       5.95          -       8.44
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.38
# 30/06/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3              4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero  *   BIF
# 3    Corporativos         3.61         -     4.84           6.61  6.51
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        4.91      5.24       4.88        -          -          -       8.08
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      4.62
# 31/07/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         4.27         -     4.51        6.13  5.52
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.15      5.34       4.93        -       9.25          -       7.56
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      4.72
# 31/08/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.58         -     5.23        6.48  6.32
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.37      5.86       5.78        -          -          -       7.54
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.52
# 30/09/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         6.11         -     5.33        7.44  6.14
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        6.89      5.93       6.42        -          -          -       7.20
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.87
# 31/10/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/10/2015
# Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
#                0            1         2        3           4     5   \
# 2  Tasa Anual (%)  Continental  Comercio  Crédito  Financiero   BIF
# 3    Corporativos         5.51         -     5.58        7.05  6.17
#
#            6         7          8        9          10         11         12  \
# 2  Scotiabank  Citibank  Interbank  Mibanco  Banco GNB  Falabella  Santander
# 3        5.87      6.15       6.05        -       8.05          -       7.77
#
#        13      14        15        16    17        18
# 2  Ripley  Azteca  Deutsche  Cencosud  ICBC  Promedio
# 3       -       -         -         -     -      5.75
# 30/11/2015
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 31/12/2015
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 31/01/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/01/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/01/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 29/02/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 31/03/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 30/04/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/04/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/04/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 31/05/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 30/06/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'Deutsche', 'CAT', 'ICBC', 'Promedio']
# 31/07/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/07/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/07/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 28/07/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 4 before
# 27/07/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/08/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/09/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/10/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/11/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/12/2016
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/12/2016
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/01/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 28/02/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/03/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/04/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/04/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/04/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 27/04/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/05/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/05/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/06/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/06/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/06/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/07/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/08/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/09/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/09/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/09/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/10/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/11/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/12/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/12/2017
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/12/2017
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/01/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 28/02/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/03/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/03/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/03/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 28/03/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 4 before
# 27/03/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/04/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/05/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/06/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/06/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/06/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 27/06/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/07/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Financiero', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/08/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/08/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/08/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/09/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/09/2018
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/09/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/10/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 30/11/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/12/2018
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/01/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 28/02/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'CAT', 'ICBC', 'Promedio']
# 31/03/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/03/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/03/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/04/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/05/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'Continental', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/06/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/06/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 28/06/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/07/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/08/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/08/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/08/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 28/08/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/09/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/10/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/10/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/11/2019
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/11/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/12/2019
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/01/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 29/02/2020
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 28/02/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/03/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/04/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/05/2020
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/05/2020
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/05/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 30/06/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Promedio']
# 31/07/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/08/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/09/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/10/2020
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/10/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/11/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/12/2020
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/01/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/01/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/01/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 28/02/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 27/02/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 26/02/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 25/02/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 4 before
# 24/02/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 5 before
# 23/02/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/03/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/04/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/05/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/06/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/07/2021
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/07/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/08/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/09/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/10/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 30/11/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Azteca', 'ICBC', 'Bank of China', 'Promedio']
# 31/12/2021
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 31/01/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 28/02/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 31/03/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 30/04/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 29/04/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 31/05/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 30/06/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 31/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 1 before
# 30/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 2 before
# 29/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 3 before
# 28/07/2022
# No Tenemos una tabla tipo antigua
# No Tenemos Una tabla Reciente
# la tabla no cumple con tener más de 5 columnas.
# GO 4 before
# 27/07/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'Promedio']
# 31/08/2022
# No Tenemos una tabla tipo antigua
# Tenemos Una tabla Reciente
# ['Tasa Anual (%)', 'BBVA', 'Comercio', 'Crédito', 'Pichincha', 'BIF', 'Scotiabank', 'Citibank', 'Interbank', 'Mibanco', 'GNB', 'Falabella', 'Santander', 'Ripley', 'Alfin', 'ICBC', 'Bank of China', 'BCI', 'Promedio']
